# %%
import pandas as pd

# %%
a = pd.read_csv("transactions.csv")
b = pd.read_csv("transactions_v2.csv")
merged = a.merge(b, on='msno')
merged.to_csv("transactions_merge.csv", index=False)

# %%
c = pd.read_csv("transactions_merge.csv")

# %%
c.head(1048576)
# Out:
#                                                  msno  payment_method_id_x  \
# 0        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 1        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 2        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 3        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 4        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 5        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 6        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 7        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 8        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 9        YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# 10       YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                   41
# ...
